# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:37, 4.57MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 3
sample_id = 119
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 3:
# Samples: 10000
# Label Counts: {0: 994, 1: 1042, 2: 965, 3: 997, 4: 990, 5: 1029, 6: 978, 7: 1015, 8: 961, 9: 1029}
# First 20 Labels: [8, 5, 0, 6, 9, 2, 8, 3, 6, 2, 7, 4, 6, 9, 0, 0, 7, 3, 7, 2]
#
# Example of Image 119:
# Image - Min Value: 3 Max Value: 236
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
import sklearn.preprocessing as preprocessing

def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    #print (np.shape(x))
    test_shape = (np.random.choice(range(1000)), 32, 32, 3)
    test_numbers = np.random.choice(range(256), test_shape)
    #print(test_shape)
    #print(test_numbers.shape)
    #print(x.shape)
    #return np.ndarray(shape=x.shape)
    a = np.divide(x, 256)
    #print (a)
    return a


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    oneHot = np.zeros((len(x), 10))
    oneHot[np.arange(len(x)), x] = 1
    return oneHot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf
import numpy as np

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,shape=[None, image_shape[0], image_shape[1], image_shape[2]],name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
   # print(x_tensor.shape)
    
    input_height=conv_ksize[0]
    input_width=conv_ksize[1]
    input_depth=int(x_tensor.shape[3])
    
    #print ('W shape --> '+ str(input_height) + ', ' + str(input_width) + ', ' + str(input_depth) + ', ' + str(conv_num_outputs))
    
    F_W = tf.Variable(tf.random_normal([input_height, input_width, input_depth, conv_num_outputs], stddev=0.1))
    F_b = tf.Variable(tf.random_normal([conv_num_outputs]))
    strides = [1,conv_strides[0],conv_strides[1],1]
    padding = 'SAME'
    conv2 = tf.nn.conv2d(x_tensor, F_W, strides, padding)
    bias = tf.nn.bias_add(conv2, F_b)
    nonLin = tf.nn.relu(bias)
    return maxpool(nonLin, pool_ksize, pool_strides)
    

def maxpool(input, pool_ksize, pool_strides):
    ksize = [1, pool_ksize[0], pool_ksize[1], 1]
    strides = [1, pool_strides[0], pool_strides[1], 1]
    padding ='SAME'
    return tf.nn.max_pool(input, ksize, strides, padding)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list() 
    dim = np.prod(shape[1:])           
    return tf.reshape(x_tensor, [-1, dim]) 
    
    #new = x_tensor.shape[1] * x_tensor.shape[2] * x_tensor.shape[3]
    #new = int(new)
    #return tf.reshape(x_tensor, [-1, new])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    
    # TODO: Implement Function 
    
    #W = tf.Variable(tf.random_normal(x_tensor.shape[1]))
    #W = tf.Variable(tf.zeros(x_tensor.shape[1]))
    #W = tf.Variable(tf.random_normal([x_tensor.shape[0],num_outputs]))
    
     #W = tf.placeholder("float32", [None, num_outputs])
    #W = tf.Variable(tf.random_normal([input_height, num_outputs]))
    
    datasize = x_tensor.get_shape().as_list()[1]
    W = tf.Variable(tf.truncated_normal([datasize, num_outputs], stddev=0.1))
    #print(str(datasize))
   
    #W = tf.placeholder("float32", [x_tensor.shape[1], num_outputs])
    b = tf.Variable(tf.zeros(num_outputs))
    fc = tf.add(tf.matmul(x_tensor, W), b)
    fc = tf.nn.relu(fc)
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    #W = tf.placeholder("float32", [x_tensor.shape[1], num_outputs])
    datasize = x_tensor.get_shape().as_list()[1]
    W = tf.Variable(tf.truncated_normal([datasize, num_outputs]))
    b = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor, W), b)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    
    
    #conv_ksize = (2, 2)
    #conv_strides = (2, 2)
    #pool_ksize = (2, 2)
    #pool_strides = (2, 2)
    
    conv_ksize = (4, 4)
    conv_strides = (2, 2)
    pool_ksize = (2, 2)
    pool_strides = (2, 2)
    
    
    conv_num_outputs_c1=64
    conv = conv2d_maxpool(x, conv_num_outputs_c1, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    
    conv_ksize_2 = (2, 2)
    conv_strides_2 = (1, 1)
    pool_ksize_2 = (2, 2)
    pool_strides_2 = (2, 2)
    
    
    conv_num_outputs_c2=128
    conv = conv2d_maxpool(conv, conv_num_outputs_c2, conv_ksize_2, conv_strides_2, pool_ksize_2, pool_strides_2)
    
    conv_ksize_2 = (2, 2)
    conv_strides_2 = (2, 2)
    pool_ksize_2 = (2, 2)
    pool_strides_2 = (2, 2)
    
    conv_num_outputs_c3=256
    conv = conv2d_maxpool(conv, conv_num_outputs_c3, conv_ksize, conv_strides, pool_ksize, pool_strides)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    flat= flatten(conv)
    #flat= tf.nn.dropout(flat, keep_prob)
    
    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    num_outputs_fc_1 = 256
    fc = fully_conn(flat, num_outputs_fc_1)
    fc = tf.nn.dropout(fc, keep_prob)
    
    #num_outputs_fc_2 = 512
    #fc= fully_conn(fc, num_outputs_fc_2)
    #fc = tf.nn.dropout(fc, keep_prob)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    num_outputs_out = 10
    model= output(fc, num_outputs_out)
    
    # TODO: return output
    return model


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    #print ('train_neural_network ' + str(keep_probability))
    session.run(optimizer, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    loss = session.run(cost, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: keep_probability})
    valid_acc = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: keep_probability})

    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(loss,valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 512
keep_probability = 0.7

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            #print(str(keep_probability))
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:    11.2216 Validation Accuracy: 0.112000
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.3241 Validation Accuracy: 0.141400
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.2591 Validation Accuracy: 0.163400
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.1735 Validation Accuracy: 0.197800
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.1602 Validation Accuracy: 0.204400
# Epoch  6, CIFAR-10 Batch 1:  Loss:     2.1391 Validation Accuracy: 0.209800
# Epoch  7, CIFAR-10 Batch 1:  Loss:     2.1020 Validation Accuracy: 0.235800
# Epoch  8, CIFAR-10 Batch 1:  Loss:     2.0492 Validation Accuracy: 0.250400
# Epoch  9, CIFAR-10 Batch 1:  Loss:     2.0733 Validation Accuracy: 0.266200
# Epoch 10, CIFAR-10 Batch 1:  Loss:     2.0011 Validation Accuracy: 0.273400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.9947 Validation Accuracy: 0.279800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.9561 Validation Accuracy: 0.288600
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.9919 Validation Accuracy: 0.290400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.9001 Validation Accuracy: 0.283600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.9392 Validation Accuracy: 0.312800
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.8503 Validation Accuracy: 0.315600
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.8230 Validation Accuracy: 0.322800
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.8505 Validation Accuracy: 0.335400
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.8532 Validation Accuracy: 0.334800
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.7728 Validation Accuracy: 0.338000
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.7662 Validation Accuracy: 0.330200
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.7062 Validation Accuracy: 0.352600
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.7030 Validation Accuracy: 0.362200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.6671 Validation Accuracy: 0.360200
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.6899 Validation Accuracy: 0.358000
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.7131 Validation Accuracy: 0.355400
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.6111 Validation Accuracy: 0.358000
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.6679 Validation Accuracy: 0.354600
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.5597 Validation Accuracy: 0.379400
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.6211 Validation Accuracy: 0.375800
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.5522 Validation Accuracy: 0.383600
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.5780 Validation Accuracy: 0.379000
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.5683 Validation Accuracy: 0.368000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     1.6193 Validation Accuracy: 0.398200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     1.5057 Validation Accuracy: 0.397600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.5035 Validation Accuracy: 0.392000
# Epoch 37, CIFAR-10 Batch 1:  Loss:     1.5372 Validation Accuracy: 0.401200
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.5234 Validation Accuracy: 0.391600
# Epoch 39, CIFAR-10 Batch 1:  Loss:     1.4442 Validation Accuracy: 0.399400
# Epoch 40, CIFAR-10 Batch 1:  Loss:     1.5138 Validation Accuracy: 0.411600
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.4659 Validation Accuracy: 0.406600
# Epoch 42, CIFAR-10 Batch 1:  Loss:     1.4965 Validation Accuracy: 0.412400
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.5087 Validation Accuracy: 0.413000
# Epoch 44, CIFAR-10 Batch 1:  Loss:     1.4306 Validation Accuracy: 0.428400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     1.3875 Validation Accuracy: 0.429400
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1.4190 Validation Accuracy: 0.419600
# Epoch 47, CIFAR-10 Batch 1:  Loss:     1.3930 Validation Accuracy: 0.431400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     1.4002 Validation Accuracy: 0.419000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     1.3261 Validation Accuracy: 0.424200
# Epoch 50, CIFAR-10 Batch 1:  Loss:     1.3108 Validation Accuracy: 0.427400
# Epoch 51, CIFAR-10 Batch 1:  Loss:     1.3665 Validation Accuracy: 0.425600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     1.3708 Validation Accuracy: 0.430400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     1.3411 Validation Accuracy: 0.422800
# Epoch 54, CIFAR-10 Batch 1:  Loss:     1.3117 Validation Accuracy: 0.423800
# Epoch 55, CIFAR-10 Batch 1:  Loss:     1.2629 Validation Accuracy: 0.438600
# Epoch 56, CIFAR-10 Batch 1:  Loss:     1.2460 Validation Accuracy: 0.440000
# Epoch 57, CIFAR-10 Batch 1:  Loss:     1.2497 Validation Accuracy: 0.437800
# Epoch 58, CIFAR-10 Batch 1:  Loss:     1.2442 Validation Accuracy: 0.437200
# Epoch 59, CIFAR-10 Batch 1:  Loss:     1.1794 Validation Accuracy: 0.445200
# Epoch 60, CIFAR-10 Batch 1:  Loss:     1.2269 Validation Accuracy: 0.443200
# Epoch 61, CIFAR-10 Batch 1:  Loss:     1.1968 Validation Accuracy: 0.444200
# Epoch 62, CIFAR-10 Batch 1:  Loss:     1.1988 Validation Accuracy: 0.441000
# Epoch 63, CIFAR-10 Batch 1:  Loss:     1.1877 Validation Accuracy: 0.444800
# Epoch 64, CIFAR-10 Batch 1:  Loss:     1.1866 Validation Accuracy: 0.432000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     1.2388 Validation Accuracy: 0.434400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     1.1671 Validation Accuracy: 0.439200
# Epoch 67, CIFAR-10 Batch 1:  Loss:     1.1178 Validation Accuracy: 0.447200
# Epoch 68, CIFAR-10 Batch 1:  Loss:     1.1690 Validation Accuracy: 0.433800
# Epoch 69, CIFAR-10 Batch 1:  Loss:     1.0745 Validation Accuracy: 0.433000
# Epoch 70, CIFAR-10 Batch 1:  Loss:     1.1726 Validation Accuracy: 0.439000
# Epoch 71, CIFAR-10 Batch 1:  Loss:     1.1581 Validation Accuracy: 0.444000
# Epoch 72, CIFAR-10 Batch 1:  Loss:     1.0790 Validation Accuracy: 0.434800
# Epoch 73, CIFAR-10 Batch 1:  Loss:     1.0855 Validation Accuracy: 0.448400
# Epoch 74, CIFAR-10 Batch 1:  Loss:     1.0249 Validation Accuracy: 0.457600
# Epoch 75, CIFAR-10 Batch 1:  Loss:     1.1077 Validation Accuracy: 0.461600
# Epoch 76, CIFAR-10 Batch 1:  Loss:     1.0038 Validation Accuracy: 0.461800
# Epoch 77, CIFAR-10 Batch 1:  Loss:     1.0531 Validation Accuracy: 0.455400
# Epoch 78, CIFAR-10 Batch 1:  Loss:     1.0087 Validation Accuracy: 0.470600
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.9802 Validation Accuracy: 0.471400
# Epoch 80, CIFAR-10 Batch 1:  Loss:     1.0072 Validation Accuracy: 0.463400
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.9798 Validation Accuracy: 0.468600
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.9916 Validation Accuracy: 0.450600
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.9576 Validation Accuracy: 0.462000
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.8900 Validation Accuracy: 0.458400
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.8844 Validation Accuracy: 0.477600
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.9148 Validation Accuracy: 0.471600
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.8795 Validation Accuracy: 0.465000
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.8820 Validation Accuracy: 0.470400
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.8034 Validation Accuracy: 0.472800
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.8516 Validation Accuracy: 0.475600
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.8780 Validation Accuracy: 0.462000
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.8719 Validation Accuracy: 0.463200
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.8174 Validation Accuracy: 0.472400
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.8220 Validation Accuracy: 0.470400
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.8165 Validation Accuracy: 0.471400
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.8605 Validation Accuracy: 0.472400
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.7891 Validation Accuracy: 0.478400
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.7461 Validation Accuracy: 0.486000
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.8333 Validation Accuracy: 0.475800
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.7418 Validation Accuracy: 0.484800

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     8.5414 Validation Accuracy: 0.125800
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.4334 Validation Accuracy: 0.151000
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.1378 Validation Accuracy: 0.191600
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.0767 Validation Accuracy: 0.224200
# Epoch  1, CIFAR-10 Batch 5:  Loss:     2.0429 Validation Accuracy: 0.235800
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.1236 Validation Accuracy: 0.249600
# Epoch  2, CIFAR-10 Batch 2:  Loss:     2.0495 Validation Accuracy: 0.259000
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.9844 Validation Accuracy: 0.258200
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.9023 Validation Accuracy: 0.277400
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.9045 Validation Accuracy: 0.282200
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.0197 Validation Accuracy: 0.303800
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.8972 Validation Accuracy: 0.295600
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.8483 Validation Accuracy: 0.315400
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.7912 Validation Accuracy: 0.313000
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.8536 Validation Accuracy: 0.327400
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.9645 Validation Accuracy: 0.337200
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.7843 Validation Accuracy: 0.354600
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.6953 Validation Accuracy: 0.341000
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.6977 Validation Accuracy: 0.349800
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.7515 Validation Accuracy: 0.356200
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.8955 Validation Accuracy: 0.364400
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.7611 Validation Accuracy: 0.358200
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.6018 Validation Accuracy: 0.370800
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.5953 Validation Accuracy: 0.376400
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.6553 Validation Accuracy: 0.378200
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.7350 Validation Accuracy: 0.392200
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.6105 Validation Accuracy: 0.393200
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.5032 Validation Accuracy: 0.397400
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.5155 Validation Accuracy: 0.392800
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.5966 Validation Accuracy: 0.408800
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.7101 Validation Accuracy: 0.410800
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.6125 Validation Accuracy: 0.404200
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.4857 Validation Accuracy: 0.421000
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.5503 Validation Accuracy: 0.411800
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.5611 Validation Accuracy: 0.406000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.6602 Validation Accuracy: 0.420400
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.5685 Validation Accuracy: 0.412600
# Epoch  8, CIFAR-10 Batch 3:  Loss:     1.4657 Validation Accuracy: 0.419200
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.4022 Validation Accuracy: 0.419400
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.4618 Validation Accuracy: 0.436800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.6088 Validation Accuracy: 0.427600
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.5257 Validation Accuracy: 0.440200
# Epoch  9, CIFAR-10 Batch 3:  Loss:     1.3915 Validation Accuracy: 0.426600
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.4585 Validation Accuracy: 0.443200
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.4650 Validation Accuracy: 0.447800
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.6048 Validation Accuracy: 0.438400
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.4889 Validation Accuracy: 0.436800
# Epoch 10, CIFAR-10 Batch 3:  Loss:     1.3809 Validation Accuracy: 0.437400
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.3886 Validation Accuracy: 0.444200
# Epoch 10, CIFAR-10 Batch 5:  Loss:     1.4204 Validation Accuracy: 0.458400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.6437 Validation Accuracy: 0.448000
# Epoch 11, CIFAR-10 Batch 2:  Loss:     1.4044 Validation Accuracy: 0.450200
# Epoch 11, CIFAR-10 Batch 3:  Loss:     1.3312 Validation Accuracy: 0.448600
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.3253 Validation Accuracy: 0.458600
# Epoch 11, CIFAR-10 Batch 5:  Loss:     1.3397 Validation Accuracy: 0.442000
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.5177 Validation Accuracy: 0.459200
# Epoch 12, CIFAR-10 Batch 2:  Loss:     1.4218 Validation Accuracy: 0.460800
# Epoch 12, CIFAR-10 Batch 3:  Loss:     1.3315 Validation Accuracy: 0.472800
# Epoch 12, CIFAR-10 Batch 4:  Loss:     1.4178 Validation Accuracy: 0.448200
# Epoch 12, CIFAR-10 Batch 5:  Loss:     1.3791 Validation Accuracy: 0.461200
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.5169 Validation Accuracy: 0.469400
# Epoch 13, CIFAR-10 Batch 2:  Loss:     1.3769 Validation Accuracy: 0.472200
# Epoch 13, CIFAR-10 Batch 3:  Loss:     1.2634 Validation Accuracy: 0.468000
# Epoch 13, CIFAR-10 Batch 4:  Loss:     1.2885 Validation Accuracy: 0.469800
# Epoch 13, CIFAR-10 Batch 5:  Loss:     1.3079 Validation Accuracy: 0.471400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.5333 Validation Accuracy: 0.480800
# Epoch 14, CIFAR-10 Batch 2:  Loss:     1.3988 Validation Accuracy: 0.465800
# Epoch 14, CIFAR-10 Batch 3:  Loss:     1.2877 Validation Accuracy: 0.475400
# Epoch 14, CIFAR-10 Batch 4:  Loss:     1.3029 Validation Accuracy: 0.471600
# Epoch 14, CIFAR-10 Batch 5:  Loss:     1.3247 Validation Accuracy: 0.472000
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.4467 Validation Accuracy: 0.484000
# Epoch 15, CIFAR-10 Batch 2:  Loss:     1.3469 Validation Accuracy: 0.479800
# Epoch 15, CIFAR-10 Batch 3:  Loss:     1.2718 Validation Accuracy: 0.478600
# Epoch 15, CIFAR-10 Batch 4:  Loss:     1.2264 Validation Accuracy: 0.486800
# Epoch 15, CIFAR-10 Batch 5:  Loss:     1.2843 Validation Accuracy: 0.493200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.4721 Validation Accuracy: 0.463400
# Epoch 16, CIFAR-10 Batch 2:  Loss:     1.2756 Validation Accuracy: 0.497000
# Epoch 16, CIFAR-10 Batch 3:  Loss:     1.2437 Validation Accuracy: 0.480800
# Epoch 16, CIFAR-10 Batch 4:  Loss:     1.1839 Validation Accuracy: 0.482400
# Epoch 16, CIFAR-10 Batch 5:  Loss:     1.2409 Validation Accuracy: 0.496400
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.4062 Validation Accuracy: 0.475000
# Epoch 17, CIFAR-10 Batch 2:  Loss:     1.2585 Validation Accuracy: 0.484000
# Epoch 17, CIFAR-10 Batch 3:  Loss:     1.2356 Validation Accuracy: 0.488400
# Epoch 17, CIFAR-10 Batch 4:  Loss:     1.1840 Validation Accuracy: 0.488800
# Epoch 17, CIFAR-10 Batch 5:  Loss:     1.2511 Validation Accuracy: 0.508000
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.3594 Validation Accuracy: 0.494600
# Epoch 18, CIFAR-10 Batch 2:  Loss:     1.3066 Validation Accuracy: 0.481400
# Epoch 18, CIFAR-10 Batch 3:  Loss:     1.2453 Validation Accuracy: 0.507000
# Epoch 18, CIFAR-10 Batch 4:  Loss:     1.1817 Validation Accuracy: 0.505200
# Epoch 18, CIFAR-10 Batch 5:  Loss:     1.2026 Validation Accuracy: 0.494400
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.3016 Validation Accuracy: 0.510000
# Epoch 19, CIFAR-10 Batch 2:  Loss:     1.2793 Validation Accuracy: 0.499000
# Epoch 19, CIFAR-10 Batch 3:  Loss:     1.1295 Validation Accuracy: 0.513400
# Epoch 19, CIFAR-10 Batch 4:  Loss:     1.1043 Validation Accuracy: 0.502000
# Epoch 19, CIFAR-10 Batch 5:  Loss:     1.2600 Validation Accuracy: 0.511600
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.2965 Validation Accuracy: 0.506600
# Epoch 20, CIFAR-10 Batch 2:  Loss:     1.2014 Validation Accuracy: 0.521600
# Epoch 20, CIFAR-10 Batch 3:  Loss:     1.1164 Validation Accuracy: 0.517000
# Epoch 20, CIFAR-10 Batch 4:  Loss:     1.0716 Validation Accuracy: 0.512400
# Epoch 20, CIFAR-10 Batch 5:  Loss:     1.1939 Validation Accuracy: 0.517000
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.2760 Validation Accuracy: 0.522400
# Epoch 21, CIFAR-10 Batch 2:  Loss:     1.2184 Validation Accuracy: 0.510800
# Epoch 21, CIFAR-10 Batch 3:  Loss:     1.0881 Validation Accuracy: 0.525800
# Epoch 21, CIFAR-10 Batch 4:  Loss:     1.0995 Validation Accuracy: 0.523000
# Epoch 21, CIFAR-10 Batch 5:  Loss:     1.1081 Validation Accuracy: 0.510800
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.2271 Validation Accuracy: 0.535200
# Epoch 22, CIFAR-10 Batch 2:  Loss:     1.1858 Validation Accuracy: 0.514800
# Epoch 22, CIFAR-10 Batch 3:  Loss:     1.0742 Validation Accuracy: 0.520600
# Epoch 22, CIFAR-10 Batch 4:  Loss:     1.0510 Validation Accuracy: 0.532400
# Epoch 22, CIFAR-10 Batch 5:  Loss:     1.1546 Validation Accuracy: 0.528200
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.1875 Validation Accuracy: 0.532600
# Epoch 23, CIFAR-10 Batch 2:  Loss:     1.1658 Validation Accuracy: 0.526400
# Epoch 23, CIFAR-10 Batch 3:  Loss:     1.0755 Validation Accuracy: 0.528400
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.9990 Validation Accuracy: 0.529000
# Epoch 23, CIFAR-10 Batch 5:  Loss:     1.1214 Validation Accuracy: 0.525600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.1549 Validation Accuracy: 0.534200
# Epoch 24, CIFAR-10 Batch 2:  Loss:     1.1320 Validation Accuracy: 0.513200
# Epoch 24, CIFAR-10 Batch 3:  Loss:     1.0717 Validation Accuracy: 0.524600
# Epoch 24, CIFAR-10 Batch 4:  Loss:     1.0082 Validation Accuracy: 0.527800
# Epoch 24, CIFAR-10 Batch 5:  Loss:     1.0387 Validation Accuracy: 0.541800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.1555 Validation Accuracy: 0.536000
# Epoch 25, CIFAR-10 Batch 2:  Loss:     1.1669 Validation Accuracy: 0.532600
# Epoch 25, CIFAR-10 Batch 3:  Loss:     1.0492 Validation Accuracy: 0.533200
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.9462 Validation Accuracy: 0.534200
# Epoch 25, CIFAR-10 Batch 5:  Loss:     1.0714 Validation Accuracy: 0.528000
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.1750 Validation Accuracy: 0.537800
# Epoch 26, CIFAR-10 Batch 2:  Loss:     1.0303 Validation Accuracy: 0.544800
# Epoch 26, CIFAR-10 Batch 3:  Loss:     1.0143 Validation Accuracy: 0.532800
# Epoch 26, CIFAR-10 Batch 4:  Loss:     1.0034 Validation Accuracy: 0.542400
# Epoch 26, CIFAR-10 Batch 5:  Loss:     1.0630 Validation Accuracy: 0.530600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.1036 Validation Accuracy: 0.543200
# Epoch 27, CIFAR-10 Batch 2:  Loss:     1.0579 Validation Accuracy: 0.535800
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.9275 Validation Accuracy: 0.539400
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.9928 Validation Accuracy: 0.544600
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.9925 Validation Accuracy: 0.553200
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.0829 Validation Accuracy: 0.544800
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.9873 Validation Accuracy: 0.555800
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.9377 Validation Accuracy: 0.544600
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.9838 Validation Accuracy: 0.556400
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.9815 Validation Accuracy: 0.549000
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.0584 Validation Accuracy: 0.545200
# Epoch 29, CIFAR-10 Batch 2:  Loss:     1.0682 Validation Accuracy: 0.547600
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.9890 Validation Accuracy: 0.547200
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.9396 Validation Accuracy: 0.554800
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.9799 Validation Accuracy: 0.545000
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.0466 Validation Accuracy: 0.546200
# Epoch 30, CIFAR-10 Batch 2:  Loss:     1.0272 Validation Accuracy: 0.536200
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.8958 Validation Accuracy: 0.548600
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.8929 Validation Accuracy: 0.552600
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.9375 Validation Accuracy: 0.540600
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.0238 Validation Accuracy: 0.539400
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.9340 Validation Accuracy: 0.546000
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.9252 Validation Accuracy: 0.556200
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.8944 Validation Accuracy: 0.564400
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.9559 Validation Accuracy: 0.557000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.9841 Validation Accuracy: 0.559000
# Epoch 32, CIFAR-10 Batch 2:  Loss:     1.0008 Validation Accuracy: 0.547000
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.8494 Validation Accuracy: 0.550600
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.8768 Validation Accuracy: 0.572600
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.9415 Validation Accuracy: 0.543000
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.9360 Validation Accuracy: 0.547800
# Epoch 33, CIFAR-10 Batch 2:  Loss:     1.0216 Validation Accuracy: 0.550400
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.8565 Validation Accuracy: 0.554800
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.8590 Validation Accuracy: 0.566000
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.8747 Validation Accuracy: 0.573200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.9875 Validation Accuracy: 0.548400
# Epoch 34, CIFAR-10 Batch 2:  Loss:     1.0506 Validation Accuracy: 0.548800
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.8917 Validation Accuracy: 0.550800
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.8447 Validation Accuracy: 0.556800
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.8332 Validation Accuracy: 0.559200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.8895 Validation Accuracy: 0.562400
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.9706 Validation Accuracy: 0.564000
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.8331 Validation Accuracy: 0.559800
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.7937 Validation Accuracy: 0.573200
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.8054 Validation Accuracy: 0.570600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.8865 Validation Accuracy: 0.557600
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.9599 Validation Accuracy: 0.560400
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.8326 Validation Accuracy: 0.569000
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.8203 Validation Accuracy: 0.560800
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.7954 Validation Accuracy: 0.579200
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.9284 Validation Accuracy: 0.559000
# Epoch 37, CIFAR-10 Batch 2:  Loss:     1.0157 Validation Accuracy: 0.571000
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.7805 Validation Accuracy: 0.568800
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.7823 Validation Accuracy: 0.574600
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.7950 Validation Accuracy: 0.582200
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.8847 Validation Accuracy: 0.570000
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.9185 Validation Accuracy: 0.552800
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.7691 Validation Accuracy: 0.584600
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.7544 Validation Accuracy: 0.575600
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.7642 Validation Accuracy: 0.589600
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.8256 Validation Accuracy: 0.581200
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.8610 Validation Accuracy: 0.560800
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.8120 Validation Accuracy: 0.574600
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.7567 Validation Accuracy: 0.570400
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.7875 Validation Accuracy: 0.578200
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.7912 Validation Accuracy: 0.581400
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.8122 Validation Accuracy: 0.571200
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.7350 Validation Accuracy: 0.576800
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.7489 Validation Accuracy: 0.580000
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.7788 Validation Accuracy: 0.587400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.7606 Validation Accuracy: 0.580200
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.8432 Validation Accuracy: 0.574000
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.6766 Validation Accuracy: 0.588400
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.6866 Validation Accuracy: 0.585600
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.7481 Validation Accuracy: 0.584000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.7120 Validation Accuracy: 0.588200
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.8588 Validation Accuracy: 0.556400
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.6938 Validation Accuracy: 0.588000
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.6728 Validation Accuracy: 0.585000
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.7065 Validation Accuracy: 0.594400
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.7537 Validation Accuracy: 0.581800
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.8298 Validation Accuracy: 0.577600
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.7068 Validation Accuracy: 0.592600
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.7015 Validation Accuracy: 0.578000
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.6967 Validation Accuracy: 0.594000
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.7372 Validation Accuracy: 0.581000
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.8235 Validation Accuracy: 0.554600
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.7080 Validation Accuracy: 0.587200
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.7166 Validation Accuracy: 0.571600
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.7613 Validation Accuracy: 0.593600
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.7179 Validation Accuracy: 0.581400
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.7883 Validation Accuracy: 0.580600
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.7046 Validation Accuracy: 0.589200
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.6762 Validation Accuracy: 0.573400
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.6551 Validation Accuracy: 0.597800
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.7103 Validation Accuracy: 0.583000
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.7119 Validation Accuracy: 0.582200
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.6311 Validation Accuracy: 0.600600
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.6216 Validation Accuracy: 0.580400
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.6505 Validation Accuracy: 0.589000
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.7132 Validation Accuracy: 0.586600
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.7558 Validation Accuracy: 0.587000
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.6406 Validation Accuracy: 0.617200
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.6365 Validation Accuracy: 0.578600
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.7425 Validation Accuracy: 0.584200
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.6690 Validation Accuracy: 0.597600
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.6877 Validation Accuracy: 0.581200
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.6353 Validation Accuracy: 0.598200
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.5714 Validation Accuracy: 0.596600
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.6106 Validation Accuracy: 0.607000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.6076 Validation Accuracy: 0.600200
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.7040 Validation Accuracy: 0.592200
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.6070 Validation Accuracy: 0.601600
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.5915 Validation Accuracy: 0.593000
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.6492 Validation Accuracy: 0.600200
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.6245 Validation Accuracy: 0.590200
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.7186 Validation Accuracy: 0.593000
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.5535 Validation Accuracy: 0.608400
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.5829 Validation Accuracy: 0.598600
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.5800 Validation Accuracy: 0.610200
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.6279 Validation Accuracy: 0.598000
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.6593 Validation Accuracy: 0.599000
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.5233 Validation Accuracy: 0.607200
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.5621 Validation Accuracy: 0.592200
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.5628 Validation Accuracy: 0.610600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.5857 Validation Accuracy: 0.600000
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.6667 Validation Accuracy: 0.599000
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.5408 Validation Accuracy: 0.607200
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.5569 Validation Accuracy: 0.601600
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.5547 Validation Accuracy: 0.606000
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.5624 Validation Accuracy: 0.597800
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.6769 Validation Accuracy: 0.598200
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.5257 Validation Accuracy: 0.615200
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.5305 Validation Accuracy: 0.602400
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.5271 Validation Accuracy: 0.606600
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.5343 Validation Accuracy: 0.608000
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.6255 Validation Accuracy: 0.586000
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.4952 Validation Accuracy: 0.604800
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.4821 Validation Accuracy: 0.605200
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.5187 Validation Accuracy: 0.615000
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.5324 Validation Accuracy: 0.613400
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.5773 Validation Accuracy: 0.599400
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.4835 Validation Accuracy: 0.620400
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.4707 Validation Accuracy: 0.610800
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.5079 Validation Accuracy: 0.619000
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.5340 Validation Accuracy: 0.606800
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.6099 Validation Accuracy: 0.598200
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.4582 Validation Accuracy: 0.621800
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.4865 Validation Accuracy: 0.598800
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.4719 Validation Accuracy: 0.604000
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.5182 Validation Accuracy: 0.606200
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.5988 Validation Accuracy: 0.586200
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.4469 Validation Accuracy: 0.609400
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.4146 Validation Accuracy: 0.605000
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.4830 Validation Accuracy: 0.611600
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.4708 Validation Accuracy: 0.607800
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.6087 Validation Accuracy: 0.587800
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.4873 Validation Accuracy: 0.607200
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.4232 Validation Accuracy: 0.588800
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.4106 Validation Accuracy: 0.610600
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.5011 Validation Accuracy: 0.612600
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.5184 Validation Accuracy: 0.608000
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.4905 Validation Accuracy: 0.588600
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.4718 Validation Accuracy: 0.606000
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.4173 Validation Accuracy: 0.607800
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.4784 Validation Accuracy: 0.616200
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.4944 Validation Accuracy: 0.606400
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.4848 Validation Accuracy: 0.595600
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.4938 Validation Accuracy: 0.584600
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.4154 Validation Accuracy: 0.611000
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.5006 Validation Accuracy: 0.619200
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.4744 Validation Accuracy: 0.611400
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.4237 Validation Accuracy: 0.602000
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.4433 Validation Accuracy: 0.602600
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.3977 Validation Accuracy: 0.616400
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.4684 Validation Accuracy: 0.609800
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.4721 Validation Accuracy: 0.611800
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.4483 Validation Accuracy: 0.592800
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.4115 Validation Accuracy: 0.605200
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.4012 Validation Accuracy: 0.619600
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.5116 Validation Accuracy: 0.614600
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.5512 Validation Accuracy: 0.591000
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.4448 Validation Accuracy: 0.606200
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.4046 Validation Accuracy: 0.606800
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.3466 Validation Accuracy: 0.626600
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.4938 Validation Accuracy: 0.600000
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.5329 Validation Accuracy: 0.594800
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.4808 Validation Accuracy: 0.595000
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.4458 Validation Accuracy: 0.581400
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.3359 Validation Accuracy: 0.619600
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.4655 Validation Accuracy: 0.610400
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.4539 Validation Accuracy: 0.612600
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.4436 Validation Accuracy: 0.593400
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.4962 Validation Accuracy: 0.581600
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.3458 Validation Accuracy: 0.619200
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.4389 Validation Accuracy: 0.612600
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.4739 Validation Accuracy: 0.607800
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.4471 Validation Accuracy: 0.602800
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.3954 Validation Accuracy: 0.591600
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.3381 Validation Accuracy: 0.607000
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.4623 Validation Accuracy: 0.616600
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.4718 Validation Accuracy: 0.602000
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.3654 Validation Accuracy: 0.610800
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.4539 Validation Accuracy: 0.597200
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.3514 Validation Accuracy: 0.609800
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.4475 Validation Accuracy: 0.603800
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.4048 Validation Accuracy: 0.608600
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.3870 Validation Accuracy: 0.609800
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.3574 Validation Accuracy: 0.614800
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.2812 Validation Accuracy: 0.624000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.4064 Validation Accuracy: 0.618000
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.4360 Validation Accuracy: 0.593400
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.3555 Validation Accuracy: 0.613400
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.3283 Validation Accuracy: 0.612000
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.3094 Validation Accuracy: 0.621600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.4152 Validation Accuracy: 0.609000
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.3827 Validation Accuracy: 0.617000
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.3292 Validation Accuracy: 0.618800
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.3147 Validation Accuracy: 0.611400
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.2921 Validation Accuracy: 0.624200
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.3653 Validation Accuracy: 0.615200
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.3816 Validation Accuracy: 0.621600
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.3293 Validation Accuracy: 0.626200
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.3101 Validation Accuracy: 0.616800
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.3423 Validation Accuracy: 0.618200
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.3761 Validation Accuracy: 0.608400
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.3593 Validation Accuracy: 0.618000
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.2974 Validation Accuracy: 0.620200
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.3122 Validation Accuracy: 0.618800
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.2921 Validation Accuracy: 0.626200
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.3406 Validation Accuracy: 0.620600
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.3292 Validation Accuracy: 0.625600
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.3134 Validation Accuracy: 0.618600
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.2908 Validation Accuracy: 0.623600
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.3106 Validation Accuracy: 0.624600
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.3286 Validation Accuracy: 0.621400
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.3838 Validation Accuracy: 0.623000
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.2423 Validation Accuracy: 0.622800
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.2642 Validation Accuracy: 0.630600
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.2567 Validation Accuracy: 0.615600
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.3231 Validation Accuracy: 0.634600
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.3234 Validation Accuracy: 0.620000
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.2663 Validation Accuracy: 0.622000
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.2530 Validation Accuracy: 0.630400
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.2234 Validation Accuracy: 0.629400
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.2893 Validation Accuracy: 0.628800
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.3371 Validation Accuracy: 0.617600
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.2742 Validation Accuracy: 0.625600
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.2649 Validation Accuracy: 0.608400
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.2413 Validation Accuracy: 0.629600
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.2796 Validation Accuracy: 0.629200
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.3399 Validation Accuracy: 0.613400
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.2484 Validation Accuracy: 0.618400
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.3331 Validation Accuracy: 0.603200
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.2478 Validation Accuracy: 0.632400
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.3020 Validation Accuracy: 0.637400
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.2692 Validation Accuracy: 0.632800
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.2970 Validation Accuracy: 0.615600
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.3157 Validation Accuracy: 0.595000
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.2713 Validation Accuracy: 0.633600
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.2717 Validation Accuracy: 0.624800
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.2873 Validation Accuracy: 0.625400
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.2566 Validation Accuracy: 0.612800
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.2629 Validation Accuracy: 0.608200
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.2507 Validation Accuracy: 0.629400
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.2247 Validation Accuracy: 0.623400
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.2500 Validation Accuracy: 0.630800
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.2283 Validation Accuracy: 0.619600
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.2641 Validation Accuracy: 0.597600
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.2477 Validation Accuracy: 0.631400
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.2577 Validation Accuracy: 0.624200
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.2866 Validation Accuracy: 0.624000
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.2526 Validation Accuracy: 0.605800
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.2236 Validation Accuracy: 0.624400
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.2175 Validation Accuracy: 0.621200
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.2834 Validation Accuracy: 0.612800
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.2339 Validation Accuracy: 0.621600
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.2863 Validation Accuracy: 0.612800
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.2494 Validation Accuracy: 0.606800
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.2590 Validation Accuracy: 0.600000
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.2406 Validation Accuracy: 0.610800
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.2864 Validation Accuracy: 0.626800
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.2325 Validation Accuracy: 0.613600
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.2735 Validation Accuracy: 0.597600
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.2563 Validation Accuracy: 0.599200
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.2438 Validation Accuracy: 0.610600
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.2719 Validation Accuracy: 0.616600
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.1959 Validation Accuracy: 0.621000
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.3908 Validation Accuracy: 0.594200
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.2891 Validation Accuracy: 0.608200
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.2766 Validation Accuracy: 0.619600
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.2348 Validation Accuracy: 0.633600
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.2615 Validation Accuracy: 0.611800
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.2327 Validation Accuracy: 0.617200
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.2343 Validation Accuracy: 0.622800
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.2469 Validation Accuracy: 0.621400
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.2327 Validation Accuracy: 0.626400
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.1878 Validation Accuracy: 0.620400
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.1946 Validation Accuracy: 0.632200
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.1554 Validation Accuracy: 0.632200
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.2149 Validation Accuracy: 0.619600
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.2163 Validation Accuracy: 0.624400
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.1555 Validation Accuracy: 0.622400
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.1593 Validation Accuracy: 0.628400
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.1696 Validation Accuracy: 0.628000
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.2704 Validation Accuracy: 0.622600
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.2274 Validation Accuracy: 0.620600
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.1668 Validation Accuracy: 0.631000
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.2114 Validation Accuracy: 0.621200
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.1688 Validation Accuracy: 0.637400
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.2117 Validation Accuracy: 0.628600
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.1880 Validation Accuracy: 0.634000
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.2088 Validation Accuracy: 0.614600
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.1859 Validation Accuracy: 0.623400
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.1709 Validation Accuracy: 0.629000
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.2409 Validation Accuracy: 0.622800
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.1713 Validation Accuracy: 0.632800
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.1520 Validation Accuracy: 0.617200
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.1890 Validation Accuracy: 0.618800
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.1257 Validation Accuracy: 0.630200
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.2205 Validation Accuracy: 0.624000
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.1803 Validation Accuracy: 0.630800
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.1446 Validation Accuracy: 0.623200
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.1612 Validation Accuracy: 0.624800
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.1130 Validation Accuracy: 0.619600
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.2014 Validation Accuracy: 0.622200
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.2165 Validation Accuracy: 0.630400
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.1385 Validation Accuracy: 0.626800
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.1380 Validation Accuracy: 0.623000
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.1891 Validation Accuracy: 0.614200
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.1885 Validation Accuracy: 0.632000
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.1979 Validation Accuracy: 0.631000
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.1278 Validation Accuracy: 0.623600
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.1630 Validation Accuracy: 0.627600
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.1745 Validation Accuracy: 0.625600
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.2435 Validation Accuracy: 0.611400
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.1925 Validation Accuracy: 0.622200
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.1489 Validation Accuracy: 0.620600
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.1519 Validation Accuracy: 0.631800
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.1717 Validation Accuracy: 0.618800
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.1873 Validation Accuracy: 0.613200
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.1983 Validation Accuracy: 0.632000
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.1338 Validation Accuracy: 0.624000
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.1378 Validation Accuracy: 0.631600
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.1722 Validation Accuracy: 0.613400
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.1863 Validation Accuracy: 0.616800
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.1759 Validation Accuracy: 0.630800
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.1174 Validation Accuracy: 0.622800
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.1191 Validation Accuracy: 0.630000
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.1893 Validation Accuracy: 0.605800
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.1792 Validation Accuracy: 0.620800
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.1577 Validation Accuracy: 0.630800
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.1421 Validation Accuracy: 0.625800
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.1459 Validation Accuracy: 0.618400
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.1007 Validation Accuracy: 0.623400
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.1638 Validation Accuracy: 0.623600
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.1876 Validation Accuracy: 0.625200
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.1390 Validation Accuracy: 0.623600
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.1240 Validation Accuracy: 0.628800
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.1199 Validation Accuracy: 0.629200
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.1591 Validation Accuracy: 0.622400
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.1717 Validation Accuracy: 0.629800
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.0951 Validation Accuracy: 0.627400
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.1882 Validation Accuracy: 0.612600
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.1285 Validation Accuracy: 0.622000
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.1501 Validation Accuracy: 0.622200
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.1925 Validation Accuracy: 0.616600
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.1405 Validation Accuracy: 0.622200
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.1441 Validation Accuracy: 0.613600
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.0943 Validation Accuracy: 0.618600

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6423081368207931

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
